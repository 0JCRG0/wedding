# %%
import pandas as pd

pd.set_option("display.max_rows", None)

df = pd.read_csv("wedding_guest_list.csv")

df
# Out:
#       First name           Last name  \
# 0           Juan        Reyes García
# 1      Madeleine          Reyes Vann
# 2       Emiliano        Reyes García
# 3           Hugo         Reyes Velez
# 4          Laura        García Rojas
# 5         Renata        Reyes García
# 6         Camila    González Linares
# 7          Sandy                Vann
# 8          Marie                Vann
# 9      Nathaniel         Vann-Evason
# 10       Wulfric         Vann-Evason
# 11         Caleb               Greed
# 12        Antony               Greed
# 13          Evie           Law Greed
# 14       Eleanor               Greed
# 15         Mairi                 Law
# 16        Rafael              Macias
# 17     Ana Belem            Martinez
# 18      Santiago              Macias
# 19     Ana Paola              Macias
# 20      Baldemar              Damian
# 21         Karla              Damian
# 22        Sandra              Damian
# 23       Valeria              Damian
# ...
