# %%
import pandas as pd

pd.set_option("display.max_rows", None)

df = pd.read_csv("data/wedding_guest_list.csv")

df
# Out:
#                            First name  Last name  \
# 0            Juan Carlos Reyes García        NaN
# 1                Madeleine Reyes Vann        NaN
# 2               Emiliano Reyes García        NaN
# 3            Hugo Alberto Reyes Velez        NaN
# 4                  Laura García Rojas        NaN
# 5                 Renata Reyes García        NaN
# 6             Camila González Linares        NaN
# 7                          Sandy Vann        NaN
# 8                          Marie Vann        NaN
# 9               Nathaniel Vann-Evason        NaN
# 10                Wulfric Vann-Evason        NaN
# 11                        Caleb Greed        NaN
# 12                       Antony Greed        NaN
# 13                     Evie Law Greed        NaN
# 14                      Eleanor Greed        NaN
# 15                          Mairi Law        NaN
# 16                      Rafael Macias        NaN
# 17                 Ana Belem Martinez        NaN
# ...
